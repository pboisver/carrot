# %% [markdown]
# <a href="https://colab.research.google.com/github/pboisver/carrot/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Animal Diet Safety Analyzer
# Welcome to the interactive guide! This notebook demonstrates how to load a custom dataset (`animals.csv`) using an external Python utility module (`diet_safety.py`).
#
# ### Environment Agnostic Setup
# The cell below detects whether you are running this locally (e.g., in VS Code) or inside Google Colab, ensuring paths are appended properly either way.

# %%
import os
import sys

# 1. Check if the notebook is running in Google Colab
if "COLAB_RELEASE_TAG" in os.environ:
    print("🚀 Running in Google Colab. Setting up environment...")

    # 2. Clone your actual repository so Colab can see your files
    # !git clone https://github.com/pboisver/carrot.git
    # %cd carrot

    # Ensure the 'src' directory, which contains the 'carrot' package, is in Python's path
    sys.path.append(os.path.join(os.getcwd(), 'src'))

    # 3. Install uv into Colab's base environment
    # %pip install -q uv

    # 4. Force uv to install your exact pinned requirements from your repo
    # !uv pip install --system -r requirements.txt

    print("✅ Environment successfully configured with uv!")

else:
    # 5. If running locally in VS Code, skip the cloud setup completely
    print("💻 Running locally. Assuming your local 'uv' virtual environment is active!")
# Out:
# 🚀 Running in Google Colab. Setting up environment...
# Cloning into 'carrot'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 60 (delta 22), reused 52 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 48.21 KiB | 3.44 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/carrot/carrot
# Using Python 3.12.13 environment at: /usr
# Resolved 40 packages in 49ms
# Prepared 1 package in 972ms
# Uninstalled 1 package in 0.53ms
# Installed 1 package in 1ms
#  - carrot==0.1.0 (from file:///content/carrot)
#  + carrot==0.1.0 (from file:///content/carrot/carrot)
# ✅ Environment successfully configured with uv!

# %% [markdown]
# ## Step 1: Initialize the Module
# Now we import our custom `diet_safety` module and instantiate the manager class. It will automatically read our `animals.csv` dataset file.

# %% [markdown]
# The `reportMissingImports` warning often occurs when a linter cannot statically resolve an import path, even if the code runs correctly due to dynamic modifications to `sys.path` (like `sys.path.append(os.getcwd())` which was done in the environment setup cell). Since the code runs fine, this is a linter-specific warning rather than a runtime error.
#
# To make the warning disappear, you can add `# type: ignore` at the end of the import line.

# %%
from carrot.diet_safety import DietSafetyManager

# Create an instance of our module helper
manager = DietSafetyManager(csv_path='src/carrot/animals.csv')
print("Module loaded and data populated successfully!")
# Out:
# Module loaded and data populated successfully!

# %% [markdown]
# ## Step 2: Individual Animal Checks
# Let's check the dynamic relationship status of a few individual animals.

# %%
test_animals = ["Chicken", "Lion", "Grizzly Bear", "Alien"]

for animal in test_animals:
    status = manager.get_relationship(animal)
    print(f"{animal} -> {status}")
# Out:
# Chicken -> You eat the animal. Safe to hunt.
# Lion -> The animal eats you. Avoid.
# Grizzly Bear -> Both: Mutual danger dinner.
# Alien -> Unknown animal: Alien

# %% [markdown]
# ## Step 3: Categorized Listings
# We can extract lists of specific threats and opportunities from our data layer using the module's categorization filters.

# %%
print("Animals that ONLY eat me (Avoid):\n", manager.list_by_category('animal'))
print("\nAnimals that ONLY I eat (Safe Hunt):\n", manager.list_by_category('me'))
print("\nAnimals where we eat each other (Mutual Danger):\n", manager.list_by_category('both'))
# Out:
# Animals that ONLY eat me (Avoid):
#  ['Lion', 'Shark', 'Mosquito']
#
# Animals that ONLY I eat (Safe Hunt):
#  ['Chicken', 'Cow', 'Rabbit']
#
# Animals where we eat each other (Mutual Danger):
#  ['Grizzly Bear', 'Alligator']
